# %% [markdown]
# ##  Source Data : HR_Analytics_Kaggle.csv
#
# https://raw.githubusercontent.com/sathyanarayanankrishnan/DataScienceMasterclass/main/05%20-%20Data%20Preprocessing%20with%20EDA/Test/HR_Analytics_Kaggle.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("https://raw.githubusercontent.com/sathyanarayanankrishnan/DataScienceMasterclass/main/05%20-%20Data%20Preprocessing%20with%20EDA/Test/HR_Analytics_Kaggle.csv")

# %%
data
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
data.describe()
# Out:
#         enrollee_id  city_development_index  training_hours        target
# count  19158.000000            19158.000000    19158.000000  19158.000000
# mean   16875.358179                0.828848       65.366896      0.249348
# std     9616.292592                0.123362       60.058462      0.432647
# min        1.000000                0.448000        1.000000      0.000000
# 25%     8554.250000                0.740000       23.000000      0.000000
# 50%    16982.500000                0.903000       47.000000      0.000000
# 75%    25169.750000                0.920000       88.000000      0.000000
# max    33380.000000                0.949000      336.000000      1.000000

# %%
data.shape
# Out:
# (19158, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# last_new_job               423
# training_hours               0
# target                       0
# dtype: int64

# %%
data['gender'].unique()
# Out:
# array(['Male', nan, 'Female', 'Other'], dtype=object)

# %%
data['gender'].value_counts()
# Out:
# Male      13221
# Female     1238
# Other       191
# Name: gender, dtype: int64

# %%
data['gender'] = data['gender'].fillna(data['gender'].mode(0))

# %%
data['gender'].value_counts()
# Out:
# Male      13221
# Female     1238
# Other       191
# Name: gender, dtype: int64

# %%
data['gender'].unique()
# Out:
# array(['Male', nan, 'Female', 'Other'], dtype=object)

# %%
data['gender'] = data['gender'].fillna('Male')

# %%
data['gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
data['gender'].isna().sum()
# Out:
# 0

# %%
data['company_type'].unique()
# Out:
# array([nan, 'Pvt Ltd', 'Funded Startup', 'Early Stage Startup', 'Other',
#        'Public Sector', 'NGO'], dtype=object)

# %%
data['company_type'].value_counts()
# Out:
# Pvt Ltd                9817
# Funded Startup         1001
# Public Sector           955
# Early Stage Startup     603
# NGO                     521
# Other                   121
# Name: company_type, dtype: int64

# %%
data['company_type'] = data['company_type'].fillna('Pvt Ltd')

# %%
data['company_type'].value_counts()
# Out:
# Pvt Ltd                15957
# Funded Startup          1001
# Public Sector            955
# Early Stage Startup      603
# NGO                      521
# Other                    121
# Name: company_type, dtype: int64

# %%
data = data.reset_index().drop(columns = 'index')

# %%
data
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624   Male
# 3            33241  city_115                   0.789   Male
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855   Male
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
data.isna().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                       0
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type                 0
# last_new_job               423
# training_hours               0
# target                       0
# dtype: int64

# %%
data=data.dropna(subset = ['last_new_job'])

# %%
data=data.dropna(subset = ['enrolled_university'])

# %%
data=data.dropna(subset = ['education_level'])

# %%
data.shape
# Out:
# (19158, 14)

# %%
data.isna().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                       0
# relevent_experience          0
# enrolled_university          0
# education_level              0
# major_discipline          2222
# experience                   0
# company_size              5310
# company_type                 0
# last_new_job                 0
# training_hours               0
# target                       0
# dtype: int64

# %%
data=data.dropna(subset = ['experience'])

# %%
data.isna().sum()
# Out:
# enrollee_id               0
# city                      0
# city_development_index    0
# gender                    0
# relevent_experience       0
# enrolled_university       0
# education_level           0
# major_discipline          0
# experience                0
# company_size              0
# company_type              0
# last_new_job              0
# training_hours            0
# target                    0
# dtype: int64

# %%
data['company_size'].unique()
# Out:
# array([nan, '50-99', '<10', '10000+', '5000-9999', '1000-4999', '10/49',
#        '100-500', '500-999'], dtype=object)

# %%
data['company_size'].replace({'50-99':'75'}, inplace = True)

# %%
data['company_size'].replace({'<10':'5'}, inplace = True)

# %%
data['company_size'].replace({'10000+':'10000'}, inplace = True)

# %%
data['company_size'].replace({'5000-9999':'7500'}, inplace = True)

# %%
data['company_size'].replace({'1000-4999':'3000'}, inplace = True)

# %%
data['company_size'].replace({'10/49':'30'}, inplace = True)

# %%
data['company_size'].replace({'100-500':'300'}, inplace = True)

# %%
data['company_size'].replace({'500-999':'750'}, inplace = True)

# %%
data['company_size'].unique()
# Out:
# array([0, '75', '5', '10000', '7500', '3000', '30', '300', '750'],
#       dtype=object)

# %%
data['company_size'].value_counts()
# Out:
# 75       2950
# 300      2483
# 10000    1964
# 30       1394
# 3000     1282
# 5        1242
# 750       847
# 7500      542
# Name: company_size, dtype: int64

# %%
data['company_size'].fillna(0, inplace=True)

# %%
data['major_discipline'].unique()
# Out:
# array(['STEM', nan, 'Arts', 'Humanities', 'Business Degree', 'No Major',
#        'Other'], dtype=object)

# %%
data['major_discipline'].value_counts()
# Out:
# STEM               16215
# Humanities           653
# Other                364
# Business Degree      322
# Arts                 248
# No Major             212
# Name: major_discipline, dtype: int64

# %%
data['major_discipline'].fillna('STEM', inplace=True)

# %%
data
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624   Male
# 4              666  city_162                   0.767   Male
# 5            21651  city_176                   0.764   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855   Male
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
data_encoded = pd.get_dummies(data.select_dtypes(exclude = np.number).drop(columns = 'relevent_experience'))
data_encoded
pd.concat([data.select_dtypes(include = np.number),data_encoded], axis = 1)
# Out:
#        enrollee_id  city_development_index  training_hours  target  \
# 0             8949                   0.920              36     1.0
# 1            29725                   0.776              47     0.0
# 2            11561                   0.624              83     0.0
# 4              666                   0.767               8     0.0
# 5            21651                   0.764              24     1.0
# ...            ...                     ...             ...     ...
# 19153         7386                   0.878              42     1.0
# 19154        31398                   0.920              52     1.0
# 19155        24576                   0.920              44     0.0
# 19156         5756                   0.802              97     0.0
# 19157        23834                   0.855             127     0.0
#
#        city_city_1  city_city_10  city_city_100  city_city_101  city_city_102  \
# 0                0             0              0              0              0
# ...

# %%
data.drop(columns='enrollee_id', inplace = True)

# %%
data = data.reset_index().drop(columns = 'index')

# %%
data
# Out:
#            city  city_development_index gender      relevent_experience  \
# 0      city_103                   0.920   Male  Has relevent experience
# 1       city_40                   0.776   Male   No relevent experience
# 2       city_21                   0.624   Male   No relevent experience
# 3      city_162                   0.767   Male  Has relevent experience
# 4      city_176                   0.764   Male  Has relevent experience
# ...         ...                     ...    ...                      ...
# 18009  city_173                   0.878   Male   No relevent experience
# 18010  city_103                   0.920   Male  Has relevent experience
# 18011  city_103                   0.920   Male  Has relevent experience
# 18012   city_65                   0.802   Male  Has relevent experience
# 18013   city_67                   0.855   Male   No relevent experience
#
#       enrolled_university education_level major_discipline experience  \
# ...

# %%
import seaborn as sns

# %%
sns.histplot(data['gender'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='Count'>

# %%
sns.histplot(data['relevent_experience'])
# Out:
# <AxesSubplot:xlabel='relevent_experience', ylabel='Count'>

# %%
sns.histplot(data['major_discipline'])
# Out:
# <AxesSubplot:xlabel='major_discipline', ylabel='Count'>
