# %% [markdown]
# #Input Dataset :
# # https://raw.githubusercontent.com/sathyanarayanankrishnan/DataScience/main/Data_Science_Batch_21/Loan_Default.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("https://raw.githubusercontent.com/sathyanarayanankrishnan/DataScience/main/Data_Science_Batch_21/Loan_Default.csv")

# %%
data
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
data.describe()
# Out:
#                   ID      year   loan_amount  rate_of_interest  \
# count  148670.000000  148670.0  1.486700e+05     112231.000000
# mean    99224.500000    2019.0  3.311177e+05          4.045476
# std     42917.476598       0.0  1.839093e+05          0.561391
# min     24890.000000    2019.0  1.650000e+04          0.000000
# 25%     62057.250000    2019.0  1.965000e+05          3.625000
# 50%     99224.500000    2019.0  2.965000e+05          3.990000
# 75%    136391.750000    2019.0  4.365000e+05          4.375000
# max    173559.000000    2019.0  3.576500e+06          8.000000
#
#        Interest_rate_spread  Upfront_charges           term  property_value  \
# count         112031.000000    109028.000000  148629.000000    1.335720e+05
# mean               0.441656      3224.996127     335.136582    4.978935e+05
# std                0.513043      3251.121510      58.409084    3.599353e+05
# min               -3.638000         0.000000      96.000000    8.000000e+03
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
#  12  Interest_rate_spread       112031 non-null  float64
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# ID                               0
# year                             0
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36439
# Interest_rate_spread         36639
# Upfront_charges              39642
# term                            41
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value               15098
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# ...

# %%
data=data.dropna(subset = ['loan_purpose'])

# %%
data=data.dropna(subset = ['approv_in_adv'])

# %%
data=data.dropna(subset = ['term'])

# %%
data=data.dropna(subset = ['Neg_ammortization'])

# %%
data=data.dropna(subset = ['age'])

# %%
data=data.dropna(subset = ['submission_of_application'])

# %%
data.isna().sum()
# Out:
# ID                               0
# year                             0
# loan_limit                    3332
# Gender                           0
# approv_in_adv                    0
# loan_type                        0
# loan_purpose                     0
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36124
# Interest_rate_spread         36124
# Upfront_charges              39256
# term                             0
# Neg_ammortization                0
# interest_only                    0
# lump_sum_payment                 0
# property_value               14964
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        8918
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# ...

# %%
data['loan_limit'].unique()
# Out:
# array(['cf', nan, 'ncf'], dtype=object)

# %%
data['loan_limit'].value_counts()
# Out:
# cf     134183
# ncf      9759
# Name: loan_limit, dtype: int64

# %%
data['loan_limit'].fillna('cf', inplace=True)

# %%
data['loan_limit'].value_counts()
# Out:
# cf     137515
# ncf      9759
# Name: loan_limit, dtype: int64

# %%
data['rate_of_interest'].mean()
# Out:
# 4.043722986953332

# %%
data['rate_of_interest'].fillna(data['rate_of_interest'].mean(), inplace=True)

# %%
data['Interest_rate_spread'].mean()
# Out:
# 0.44128821232568816

# %%
data['Interest_rate_spread'].median()
# Out:
# 0.3901

# %%
data['Interest_rate_spread'].fillna(data['Interest_rate_spread'].median(), inplace=True)

# %%
data['Upfront_charges'].median()
# Out:
# 2599.325

# %%
data['Upfront_charges'].fillna(data['Upfront_charges'].median(), inplace=True)

# %%
data['property_value'].median()
# Out:
# 418000.0

# %%
data['property_value'].fillna(data['property_value'].median(), inplace=True)

# %%
data['income'].median()
# Out:
# 5760.0

# %%
data['income'].fillna(data['income'].median(), inplace=True)

# %%
data['LTV'].fillna(data['LTV'].median(), inplace=True)

# %%
data['LTV'].median()
# Out:
# 75.12254902

# %%
data['LTV'].mean()
# Out:
# 72.97837445793671

# %%
data['LTV'].mode()
# Out:
# 0    75.122549
# Name: LTV, dtype: float64

# %%
data['dtir1'].unique()
# Out:
# array([45., nan, 46., 42., 39., 40., 44., 30., 36., 51., 20., 31.,  6.,
#        35., 34., 49., 37., 41., 38., 56., 23., 28., 11., 27., 55., 22.,
#        24., 52., 33., 26., 47., 60., 25., 32., 10., 15., 53.,  7., 19.,
#        48., 59., 57.,  9., 50., 21., 58., 29., 43., 17., 54., 13., 12.,
#        16., 61., 18., 14.,  8.,  5.])

# %%
data['dtir1'].mean()
# Out:
# 37.732016936665616

# %%
data['dtir1'].median()
# Out:
# 39.0

# %%
data['dtir1'].fillna(data['dtir1'].median(), inplace=True)

# %%
data
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
data['Gender'].unique()
# Out:
# array(['Sex Not Available', 'Male', 'Joint', 'Female'], dtype=object)

# %%
data['Gender'].mode(0)
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
data['Gender'].replace({'Sex Not Available':'Male'},inplace=True)

# %%
data
# Out:
#             ID  year loan_limit  Gender approv_in_adv loan_type loan_purpose  \
# 0        24890  2019         cf    Male         nopre     type1           p1
# 1        24891  2019         cf    Male         nopre     type2           p1
# 2        24892  2019         cf    Male           pre     type1           p1
# 3        24893  2019         cf    Male         nopre     type1           p4
# 4        24894  2019         cf   Joint           pre     type1           p1
# ...        ...   ...        ...     ...           ...       ...          ...
# 148665  173555  2019         cf    Male         nopre     type1           p3
# 148666  173556  2019         cf    Male         nopre     type1           p1
# 148667  173557  2019         cf    Male         nopre     type1           p4
# 148668  173558  2019         cf  Female         nopre     type1           p4
# 148669  173559  2019         cf  Female         nopre     type1           p3
#
# ...

# %%
data['approv_in_adv'].unique()
# Out:
# array(['nopre', 'pre'], dtype=object)

# %%
data['loan_type'].unique()
# Out:
# array(['type1', 'type2', 'type3'], dtype=object)

# %%
data['loan_purpose'].unique()
# Out:
# array(['p1', 'p4', 'p3', 'p2'], dtype=object)

# %%
data['Credit_Worthiness'].unique()
# Out:
# array(['l1', 'l2'], dtype=object)

# %%
data['open_credit'].unique()
# Out:
# array(['nopc', 'opc'], dtype=object)

# %%
my_list = list(data)

# %%
my_list
# Out:
# ['ID',
#  'year',
#  'loan_limit',
#  'Gender',
#  'approv_in_adv',
#  'loan_type',
#  'loan_purpose',
#  'Credit_Worthiness',
#  'open_credit',
#  'business_or_commercial',
#  'loan_amount',
#  'rate_of_interest',
#  'Interest_rate_spread',
#  'Upfront_charges',
#  'term',
#  'Neg_ammortization',
#  'interest_only',
#  'lump_sum_payment',
#  'property_value',
#  'construction_type',
#  'occupancy_type',
#  'Secured_by',
#  'total_units',
#  'income',
#  'credit_type',
#  'Credit_Score',
#  'co-applicant_credit_type',
#  'age',
#  'submission_of_application',
#  'LTV',
#  'Region',
#  'Security_Type',
#  'Status',
#  'dtir1']

# %%
data_encoded = pd.get_dummies(data.select_dtypes(exclude = np.number).drop(columns = 'approv_in_adv'))
data_encoded
pd.concat([data.select_dtypes(include = np.number),data_encoded], axis = 1)
# Out:
#             ID  year  loan_amount  rate_of_interest  Interest_rate_spread  \
# 0        24890  2019       116500          4.043723                0.3901
# 1        24891  2019       206500          4.043723                0.3901
# 2        24892  2019       406500          4.560000                0.2000
# 3        24893  2019       456500          4.250000                0.6810
# 4        24894  2019       696500          4.000000                0.3042
# ...        ...   ...          ...               ...                   ...
# 148665  173555  2019       436500          3.125000                0.2571
# 148666  173556  2019       586500          5.190000                0.8544
# 148667  173557  2019       446500          3.125000                0.0816
# 148668  173558  2019       196500          3.500000                0.5824
# 148669  173559  2019       406500          4.375000                1.3871
#
#         Upfront_charges   term  property_value   income  Credit_Score  ...  \
# ...

# %%
data_encoded = pd.get_dummies(data.select_dtypes(exclude = np.number).drop(columns = 'Gender'))
data_encoded
pd.concat([data.select_dtypes(include = np.number),data_encoded], axis = 1)
# Out:
#             ID  year  loan_amount  rate_of_interest  Interest_rate_spread  \
# 0        24890  2019       116500          4.043723                0.3901
# 1        24891  2019       206500          4.043723                0.3901
# 2        24892  2019       406500          4.560000                0.2000
# 3        24893  2019       456500          4.250000                0.6810
# 4        24894  2019       696500          4.000000                0.3042
# ...        ...   ...          ...               ...                   ...
# 148665  173555  2019       436500          3.125000                0.2571
# 148666  173556  2019       586500          5.190000                0.8544
# 148667  173557  2019       446500          3.125000                0.0816
# 148668  173558  2019       196500          3.500000                0.5824
# 148669  173559  2019       406500          4.375000                1.3871
#
#         Upfront_charges   term  property_value   income  Credit_Score  ...  \
# ...

# %%
data_encoded = pd.get_dummies(data.select_dtypes(exclude = np.number).drop(columns = 'approv_in_adv'))
data_encoded
pd.concat([data.select_dtypes(include = np.number),data_encoded], axis = 1)
# Out:
#             ID  year  loan_amount  rate_of_interest  Interest_rate_spread  \
# 0        24890  2019       116500          4.043723                0.3901
# 1        24891  2019       206500          4.043723                0.3901
# 2        24892  2019       406500          4.560000                0.2000
# 3        24893  2019       456500          4.250000                0.6810
# 4        24894  2019       696500          4.000000                0.3042
# ...        ...   ...          ...               ...                   ...
# 148665  173555  2019       436500          3.125000                0.2571
# 148666  173556  2019       586500          5.190000                0.8544
# 148667  173557  2019       446500          3.125000                0.0816
# 148668  173558  2019       196500          3.500000                0.5824
# 148669  173559  2019       406500          4.375000                1.3871
#
#         Upfront_charges   term  property_value   income  Credit_Score  ...  \
# ...

# %%
data_encoded = pd.get_dummies(data.select_dtypes(exclude = np.number).drop(columns = 'loan_type'))
data_encoded
pd.concat([data.select_dtypes(include = np.number),data_encoded], axis = 1)
# Out:
#             ID  year  loan_amount  rate_of_interest  Interest_rate_spread  \
# 0        24890  2019       116500          4.043723                0.3901
# 1        24891  2019       206500          4.043723                0.3901
# 2        24892  2019       406500          4.560000                0.2000
# 3        24893  2019       456500          4.250000                0.6810
# 4        24894  2019       696500          4.000000                0.3042
# ...        ...   ...          ...               ...                   ...
# 148665  173555  2019       436500          3.125000                0.2571
# 148666  173556  2019       586500          5.190000                0.8544
# 148667  173557  2019       446500          3.125000                0.0816
# 148668  173558  2019       196500          3.500000                0.5824
# 148669  173559  2019       406500          4.375000                1.3871
#
#         Upfront_charges   term  property_value   income  Credit_Score  ...  \
# ...

# %%
import seaborn as sns

# %%
sns.histplot(data['loan_type'])
# Out:
# <AxesSubplot:xlabel='loan_type', ylabel='Count'>

# %%
sns.histplot(data['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %%
sns.histplot(data['approv_in_adv'])
# Out:
# <AxesSubplot:xlabel='approv_in_adv', ylabel='Count'>
